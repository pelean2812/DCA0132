# %%
#Importar as bibliotecas

from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import SparkSession

# %%
sp = SparkSession.builder \
    .appName("spark") \
    .config("spark.jars.packages",
           "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1,"
           "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1") \
    .config("spark.master", "local[*]") \
    .getOrCreate()
# Out:
# :: loading settings :: url = jar:file:/home/myuser/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/myuser/.ivy2/cache
# The jars for the packages stored in: /home/myuser/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# org.mongodb.spark#mongo-spark-connector_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3817edfd-c28a-40fb-a593-ba3b4ff1df06;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.4.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 in central
# 	found org.apache.kafka#kafka-clients;3.3.2 in central
# lz4#lz4-java;1.8.0 in central0-10_2.12;3.4.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 in central
# 	found org.apache.kafka#kafka-clients;3.3.2 in central
#
# 	found org.xerial.snappy#snappy-java;1.1.10.1 in central
# 	found org.slf4j#slf4j-api;2.0.6 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.4 in centralund org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 in central
# 	found org.apache.kafka#kafka-clients;3.3.2 in central
#
# 	found org.xerial.snappy#snappy-java;1.1.10.1 in central
# 	found org.slf4j#slf4j-api;2.0.6 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
#
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# mongodb.spark#mongo-spark-connector_2.12;10.1.1 in centralache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 in central
# 	found org.apache.kafka#kafka-clients;3.3.2 in central
#
# 	found org.xerial.snappy#snappy-java;1.1.10.1 in central
# 	found org.slf4j#slf4j-api;2.0.6 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
#
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
#
# 	found org.mongodb#mongodb-driver-sync;4.8.2 in centralralache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 in central
# 	found org.apache.kafka#kafka-clients;3.3.2 in central
#
# 	found org.xerial.snappy#snappy-java;1.1.10.1 in central
# 	found org.slf4j#slf4j-api;2.0.6 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
#
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
#
#
# 	[4.8.2] org.mongodb#mongodb-driver-sync;[4.8.1,4.8.99)
# 	found org.mongodb#bson;4.8.2 in central
# 	found org.mongodb#mongodb-driver-core;4.8.2 in central
# 	found org.mongodb#bson-record-codec;4.8.2 in central
# downloading https://repo1.maven.org/maven2/org/mongodb/spark/mongo-spark-connector_2.12/10.1.1/mongo-spark-connector_2.12-10.1.1.jar ...
# [SUCCESSFUL ] org.mongodb.spark#mongo-spark-connector_2.12;10.1.1!mongo-spark-connector_2.12.jar (346ms);3.4.1 in central
# 	found org.apache.kafka#kafka-clients;3.3.2 in central
#
# 	found org.xerial.snappy#snappy-java;1.1.10.1 in central
# 	found org.slf4j#slf4j-api;2.0.6 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
#
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
#
#
# 	[4.8.2] org.mongodb#mongodb-driver-sync;[4.8.1,4.8.99)
# 	found org.mongodb#bson;4.8.2 in central
# 	found org.mongodb#mongodb-driver-core;4.8.2 in central
# 	found org.mongodb#bson-record-codec;4.8.2 in central
# downloading https://repo1.maven.org/maven2/org/mongodb/spark/mongo-spark-connector_2.12/10.1.1/mongo-spark-connector_2.12-10.1.1.jar ...
#
# :: resolution report :: resolve 6867ms :: artifacts dl 365ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.3.2 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.4.1 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.mongodb#bson;4.8.2 from central in [default]
# 	org.mongodb#bson-record-codec;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-core;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-sync;4.8.2 from central in [default]
# 	org.mongodb.spark#mongo-spark-connector_2.12;10.1.1 from central in [default]
# 	org.slf4j#slf4j-api;2.0.6 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.1 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   16  |   2   |   1   |   0   ||   16  |   1   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-3817edfd-c28a-40fb-a593-ba3b4ff1df06
# 	confs: [default]
# 	1 artifacts copied, 15 already retrieved (152kB/16ms)
# Setting default log level to "WARN".o-spark-connector_2.12;10.1.1!mongo-spark-connector_2.12.jar (346ms);3.4.1 in central
# 	found org.apache.kafka#kafka-clients;3.3.2 in central
#
# 	found org.xerial.snappy#snappy-java;1.1.10.1 in central
# 	found org.slf4j#slf4j-api;2.0.6 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
#
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
#
#
# 	[4.8.2] org.mongodb#mongodb-driver-sync;[4.8.1,4.8.99)
# 	found org.mongodb#bson;4.8.2 in central
# 	found org.mongodb#mongodb-driver-core;4.8.2 in central
# 	found org.mongodb#bson-record-codec;4.8.2 in central
# downloading https://repo1.maven.org/maven2/org/mongodb/spark/mongo-spark-connector_2.12/10.1.1/mongo-spark-connector_2.12-10.1.1.jar ...
#
# :: resolution report :: resolve 6867ms :: artifacts dl 365ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.3.2 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.4.1 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.mongodb#bson;4.8.2 from central in [default]
# 	org.mongodb#bson-record-codec;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-core;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-sync;4.8.2 from central in [default]
# 	org.mongodb.spark#mongo-spark-connector_2.12;10.1.1 from central in [default]
# 	org.slf4j#slf4j-api;2.0.6 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.1 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   16  |   2   |   1   |   0   ||   16  |   1   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-3817edfd-c28a-40fb-a593-ba3b4ff1df06
# 	confs: [default]
# 	1 artifacts copied, 15 already retrieved (152kB/16ms)
#
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# Criar o dataframe do tipo stream, apontando para o servidor kafka e o tópico a ser consumido.
df = (sp.readStream
        .format("kafka")
        .option("kafka.bootstrap.servers", "spark-master:9092")
        .option("subscribe", "topico-mongo.spark-streaming.atletas")
        .option("startingOffsets", "earliest") 
        .load()
)

# %%
# Carregando colunas selecionadas de .CSV para MongoDB
from pyspark.sql.types import *

print("--- INICIANDO: Carga de Dados em Lote (Batch) com colunas selecionadas ---")

athletes_schema = StructType([
    StructField("code", IntegerType(), True),
    StructField("current", BooleanType(), True),
    StructField("name", StringType(), True),
    StructField("name_short", StringType(), True),
    StructField("name_tv", StringType(), True),
    StructField("gender", StringType(), True),
    StructField("function", StringType(), True),
    StructField("country_code", StringType(), True),
    StructField("country", StringType(), True),
    StructField("country_long", StringType(), True),
    StructField("nationality", StringType(), True),
    StructField("nationality_long", StringType(), True),
    StructField("nationality_code", StringType(), True),
    StructField("height", DoubleType(), True),
    StructField("weight", DoubleType(), True),
    StructField("disciplines", StringType(), True),
    StructField("events", StringType(), True),
    StructField("birth_date", StringType(), True),
    StructField("birth_place", StringType(), True),
    StructField("birth_country", StringType(), True),
    StructField("residence_place", StringType(), True),
    StructField("residence_country", StringType(), True),
    StructField("nickname", StringType(), True),
    StructField("hobbies", StringType(), True),
    StructField("occupation", StringType(), True),
    StructField("education", StringType(), True),
    StructField("family", StringType(), True),
    StructField("lang", StringType(), True),
    StructField("coach", StringType(), True),
    StructField("reason", StringType(), True),
    StructField("hero", StringType(), True),
    StructField("influence", StringType(), True),
    StructField("philosophy", StringType(), True),
    StructField("sporting_relatives", StringType(), True),
    StructField("ritual", StringType(), True),
    StructField("other_sports", StringType(), True)
])

# 2. Ler o arquivo .csv do HDFS com o schema completo
df_completo = sp.read \
    .format("csv") \
    .option("header", "true") \
    .schema(athletes_schema) \
    .load("hdfs://spark-master:9000/user/myuser/data/athletes.csv")

df_selecionado = df_completo.select(
    "name",
    "nickname",
    "nationality",
    "disciplines",
    "height",
    "weight",
    "birth_date",
    "birth_place",
    "birth_country",
    "residence_place",
    "residence_country",
)

# 4. (Opcional) Mostrar os dados do novo DataFrame para verificação
print("Dados com colunas selecionadas:")
df_selecionado.show(10, truncate=False)
# Out:
# --- INICIANDO: Carga de Dados em Lote (Batch) com colunas selecionadas ---
# Dados com colunas selecionadas:
# +------------------------+----------+-----------+-------------+------+------+-----------------------------------+-----------+-------------+---------------+-----------------+
# |name                    |nickname  |nationality|disciplines  |height|weight|birth_date                         |birth_place|birth_country|residence_place|residence_country|
# +------------------------+----------+-----------+-------------+------+------+-----------------------------------+-----------+-------------+---------------+-----------------+
# |ALEKSANYAN Artur        |White Bear|Armenia    |['Wrestling']|0.0   |0.0   |1991-10-21                         |GYUMRI     |Armenia      |GYUMRI         |Armenia          |
# |AMOYAN Malkhas          |NULL      |Armenia    |['Wrestling']|0.0   |0.0   |1999-01-22                         |YEREVAN    |Armenia      |YEREVAN        |Armenia          |
# |GALSTYAN Slavik         |NULL      |Armenia    |['Wrestling']|0.0   |0.0   |1996-12-21                         |NULL       |NULL         |YEREVAN        |Armenia          |
# |HARUTYUNYAN Arsen       |NULL      |Armenia    |['Wrestling']|0.0   |0.0   |1999-11-22                         |MASIS      |Armenia      |YEREVAN        |Armenia          |
# |TEVANYAN Vazgen         |NULL      |Armenia    |['Wrestling']|0.0   |0.0   |1999-10-27                         |POKR VEDI  |Armenia      |NULL           |Armenia          |
# |ARENAS Lorena           |Australia |Colombia   |['Athletics']|162.0 |0.0   | 'Marathon Race Walk Relay Mixed']"|1993-09-17 |PEREIRA      |Colombia       |MELBOURNE        |
# |McKENZIE Ashley         |Bad Boy   |Jamaica    |['Judo']     |0.0   |0.0   |1989-07-17                         |LONDON     |Great Britain|CAMBERLEY      |Great Britain    |
# |BASS BITTAYE Gina Mariam|NULL      |Gambia     |['Athletics']|161.0 |0.0   | ""Women's 200m""]"                |1995-05-03 |TUBAKUTA     |Gambia         |NULL             |
# |CAMARA Ebrahima         |NULL      |Gambia     |['Athletics']|178.0 |0.0   |1996-09-18                         |BUNDUNG    |Gambia       |ANGERS         |France           |
# |RUEDA SANTOS Lizeth     |NULL      |Mexico     |['Triathlon']|0.0   |0.0   |1994-03-07                         |GUADALAJARA|Mexico       |XALAPA         |Mexico           |
# +------------------------+----------+-----------+-------------+------+------+-----------------------------------+-----------+-------------+---------------+-----------------+
# only showing top 10 rows

# %%
import csv
from pymongo import MongoClient
client = MongoClient("mongodb://mongo:27017")
db = client["spark-streaming"]
collection = db["atletas"]

collection.delete_many({})

with open("athletes.csv", newline='', encoding="utf-8") as f:
    reader = csv.DictReader(f, delimiter=',')
    documentos = list(reader)
    collection.insert_many(documentos)

print(f"{len(documentos)} documentos inseridos com sucesso no MongoDB")
# Out:
# 11113 documentos inseridos com sucesso no MongoDB

# %% [markdown]
# ## Inserindo VIA JSON

# %%
schema_json = StructType([
    StructField("name", StringType(), True),
    StructField("nickname", StringType(), True),
    StructField("nationality", StringType(), True),
    StructField("disciplines", StringType(), True),
    StructField("height", DoubleType(), True),
    StructField("weight", DoubleType(), True),
    StructField("birth_date", StringType(), True),
    StructField("birth_place", StringType(), True),
    StructField("birth_country", StringType(), True),
    StructField("residence_place", StringType(), True),
    StructField("residence_country", StringType(), True)
])

df_json = sp.read \
    .format("json") \
    .option("multiLine", True) \
    .schema(schema_json) \
    .load("hdfs://spark-master:9000/user/myuser/data/atletas_ficticios_30.json")


print("Adicionando dados do JSON na coleção 'atletas'...")
df_json.show(5)
df_json.printSchema()
# Out:
# Adicionando dados do JSON na coleção 'atletas'...
# +-----------------+------------+-----------+-------------+------+------+----------+--------------+-------------+---------------+-----------------+
# |             name|    nickname|nationality|  disciplines|height|weight|birth_date|   birth_place|birth_country|residence_place|residence_country|
# +-----------------+------------+-----------+-------------+------+------+----------+--------------+-------------+---------------+-----------------+
# |      ALINE SILVA|  Aline Silv|     BRAZIL|     HANDBALL|  1.62| 55.47|1992-02-07|       GOIANIA|       BRAZIL|         MANAUS|           BRAZIL|
# |    MARIANA SILVA|Mariana Silv|     BRAZIL|   BASKETBALL|  1.96|100.49|1997-06-04|  PORTO ALEGRE|       BRAZIL| RIO DE JANEIRO|           BRAZIL|
# |   CAMILA MARTINS|    Camila M|     BRAZIL|   VOLLEYBALL|  1.67| 90.29|1993-02-04|        RECIFE|       BRAZIL|   PORTO ALEGRE|           BRAZIL|
# |CARLOS NASCIMENTO|    Carlos N|     BRAZIL|WEIGHTLIFTING|  1.68| 55.68|1997-07-06|  PORTO ALEGRE|       BRAZIL| RIO DE JANEIRO|           BRAZIL|
# | VINICIUS MARTINS|  Vinicius M|     BRAZIL| TABLE_TENNIS|  1.88| 55.32|1992-08-18|BELO HORIZONTE|       BRAZIL|         RECIFE|           BRAZIL|
# +-----------------+------------+-----------+-------------+------+------+----------+--------------+-------------+---------------+-----------------+
# only showing top 5 rows
#
# root
#  |-- name: string (nullable = true)
#  |-- nickname: string (nullable = true)
#  |-- nationality: string (nullable = true)
#  |-- disciplines: string (nullable = true)
#  |-- height: double (nullable = true)
#  |-- weight: double (nullable = true)
#  |-- birth_date: string (nullable = true)
#  |-- birth_place: string (nullable = true)
#  |-- birth_country: string (nullable = true)
#  |-- residence_place: string (nullable = true)
#  |-- residence_country: string (nullable = true)

# %%
import json
#Salvando no MongoDB
json_data = df_json.toJSON().collect()
batch_size = 100
for i in range(0, len(json_data), batch_size):
    batch = [json.loads(doc) for doc in json_data[i:i+batch_size]]
    collection.insert_many(batch)

print(f"Dados inseridos! Total: {len(json_data)} registros")
# Out:
# Dados inseridos! Total: 30 registros
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----+-------+-------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+-----------+------+----------+------------+-------------+---------------+-----------------+------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
# |code|current|name         |name_short|name_tv|gender|function|country_code|country|country_long|nationality|nationality_long|nationality_code|height|weight|disciplines|events|birth_date|birth_place |birth_country|residence_place|residence_country|nickname    |hobbies|occupation|education|family|lang|coach|reason|hero|influence|philosophy|sporting_relatives|ritual|other_sports|
# +----+-------+-------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+-----------+------+----------+------------+-------------+---------------+-----------------+------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
# |NULL|NULL   |ALINE SILVA  |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.62  |55.47 |HANDBALL   |NULL  |1992-02-07|GOIANIA     |BRAZIL       |MANAUS         |BRAZIL           |Aline Silv  |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |MARIANA SILVA|NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.96  |100.49|BASKETBALL |NULL  |1997-06-04|PORTO ALEGRE|BRAZIL       |RIO DE JANEIRO |BRAZIL           |Mariana Silv|NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# +----+-------+-------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+-----------+------+----------+------------+-------------+---------------+-----------------+------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
#
#
# Batch: 4
# -------------------------------------------
# +----+-------+------------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+-------------------+------+----------+--------------+-------------+---------------+-----------------+------------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
# |code|current|name              |name_short|name_tv|gender|function|country_code|country|country_long|nationality|nationality_long|nationality_code|height|weight|disciplines        |events|birth_date|birth_place   |birth_country|residence_place|residence_country|nickname          |hobbies|occupation|education|family|lang|coach|reason|hero|influence|philosophy|sporting_relatives|ritual|other_sports|
# +----+-------+------------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+-------------------+------+----------+--------------+-------------+---------------+-----------------+------------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
# |NULL|NULL   |CAMILA MARTINS    |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.67  |90.29 |VOLLEYBALL         |NULL  |1993-02-04|RECIFE        |BRAZIL       |PORTO ALEGRE   |BRAZIL           |Camila M          |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |CARLOS NASCIMENTO |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.68  |55.68 |WEIGHTLIFTING      |NULL  |1997-07-06|PORTO ALEGRE  |BRAZIL       |RIO DE JANEIRO |BRAZIL           |Carlos N          |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |VINICIUS MARTINS  |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.88  |55.32 |TABLE_TENNIS       |NULL  |1992-08-18|BELO HORIZONTE|BRAZIL       |RECIFE         |BRAZIL           |Vinicius M        |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |LETICIA OLIVEIRA  |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.57  |98.2  |ARTISTIC_GYMNASTICS|NULL  |1990-08-24|FORTALEZA     |BRAZIL       |PORTO ALEGRE   |BRAZIL           |Leticia Oliveir   |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |CARLOS ALMEIDA    |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.67  |48.38 |ATHLETICS          |NULL  |1996-04-24|MANAUS        |BRAZIL       |MANAUS         |BRAZIL           |Carlos Almeid     |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |LEANDRO LIMA      |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.92  |49.3  |ATHLETICS          |NULL  |1997-09-10|FORTALEZA     |BRAZIL       |CURITIBA       |BRAZIL           |Leandro Lim       |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |MARIANA SANTOS    |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.66  |84.86 |JUDO               |NULL  |1991-05-24|PORTO ALEGRE  |BRAZIL       |RECIFE         |BRAZIL           |Mariana S         |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |VINICIUS PEREIRA  |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.82  |70.24 |SAILING            |NULL  |2003-08-07|MANAUS        |BRAZIL       |RECIFE         |BRAZIL           |Vinicius Pereir   |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |THIAGO PEREIRA    |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.9   |86.39 |TABLE_TENNIS       |NULL  |1991-06-11|RECIFE        |BRAZIL       |PORTO ALEGRE   |BRAZIL           |Thiago Pereir     |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |ANDRE LIMA        |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.92  |49.84 |VOLLEYBALL         |NULL  |1994-06-15|FORTALEZA     |BRAZIL       |MANAUS         |BRAZIL           |Andre Lim         |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |VINICIUS ALMEIDA  |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.95  |62.62 |VOLLEYBALL         |NULL  |2003-09-11|PORTO ALEGRE  |BRAZIL       |RIO DE JANEIRO |BRAZIL           |Vinicius Almeid   |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |LEANDRO OLIVEIRA  |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.76  |49.08 |HANDBALL           |NULL  |1993-05-27|BELO HORIZONTE|BRAZIL       |FORTALEZA      |BRAZIL           |Leandro Oliveir   |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |MARCELO RODRIGUES |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.9   |96.23 |BOXING             |NULL  |1999-09-15|BELO HORIZONTE|BRAZIL       |SAO PAULO      |BRAZIL           |Marcelo Rodrigues |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |PATRICIA RODRIGUES|NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.97  |97.44 |HANDBALL           |NULL  |2002-02-06|GOIANIA       |BRAZIL       |MANAUS         |BRAZIL           |Patricia Rodrigues|NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |BEATRIZ COSTA     |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.58  |87.94 |ATHLETICS          |NULL  |1999-03-19|FORTALEZA     |BRAZIL       |RECIFE         |BRAZIL           |Beatriz Cost      |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |SANDRA GOMES      |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.98  |103.18|FENCING            |NULL  |1992-10-27|PORTO ALEGRE  |BRAZIL       |BELO HORIZONTE |BRAZIL           |Sandra Gomes      |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |LARISSA OLIVEIRA  |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.89  |67.3  |HANDBALL           |NULL  |1999-06-02|MANAUS        |BRAZIL       |SAO PAULO      |BRAZIL           |Larissa Oliveir   |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |LETICIA COSTA     |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.86  |85.22 |BASKETBALL         |NULL  |1991-09-16|PORTO ALEGRE  |BRAZIL       |CURITIBA       |BRAZIL           |Leticia Cost      |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |FERNANDA LIMA     |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.6   |81.74 |BOXING             |NULL  |1994-02-14|BELO HORIZONTE|BRAZIL       |MANAUS         |BRAZIL           |Fernanda Lim      |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# |NULL|NULL   |THIAGO SANTOS     |NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.92  |71.84 |BASKETBALL         |NULL  |2003-11-01|MANAUS        |BRAZIL       |FORTALEZA      |BRAZIL           |Thiago S          |NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# +----+-------+------------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+-------------------+------+----------+--------------+-------------+---------------+-----------------+------------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
# only showing top 20 rows

# %%
# ==============================================================================
# PARTE 2: PROCESSAMENTO EM TEMPO REAL (STREAMING - Kafka para MongoDB)
# ==============================================================================

print("\n--- INICIANDO PARTE 2: Processamento em Tempo Real (Streaming) ---")

# Ler o stream do tópico Kafka que recebe as alterações do Debezium
df_kafka = sp.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "spark-master:9092") \
    .option("subscribe", "topico-mongo.spark-streaming.atletas") \
    .option("startingOffsets", "latest") \
    .load()
# Out:
# --- INICIANDO PARTE 2: Processamento em Tempo Real (Streaming) ---

# %%
# Schema para a mensagem completa do Debezium (conforme o .ipynb)
debezium_schema = StructType([
    StructField("payload", StructType([
        StructField("after", StringType(), True),
        StructField("op", StringType(), True),
    ]), True)
])

# Transformar os dados do Kafka
dx = df_kafka.select(from_json(df_kafka.value.cast("string"), debezium_schema).alias("data")) \
       .select("data.payload.after") \
       .withColumn("athlete_data", from_json(col("after"), athletes_schema)) \
       .select("athlete_data.*")
# Out:
# 25/07/20 20:19:33 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
# Escrever o stream processado na coleção de DESTINO no MongoDB.
print("Aguardando novos dados do Kafka para processar e salvar na coleção de destino...")
ds = dx.writeStream \
    .outputMode("append") \
    .format("console") \
    .option("truncate", False) \
    .start()
# Out:
# 25/07/20 20:19:33 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-fcc78760-3677-4e8e-a20e-a101336f1d93. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# Aguardando novos dados do Kafka para processar e salvar na coleção de destino...
# 25/07/20 20:19:33 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 25/07/20 20:19:35 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
#                                                                                 r, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 1:>                                                          (0 + 1) / 1]r, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----+-------+---------------------+--------------+---------------------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+---------------------------------+-------------------------------------------------------------+----------+--------------------+-------------+---------------+-----------------+-----------------------+------------------------------------------------------------+--------------------+---------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------+------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------+
# |code|current|name                 |name_short    |name_tv              |gender|function|country_code|country|country_long|nationality|nationality_long|nationality_code|height|weight|disciplines                      |events                                                       |birth_date|birth_place         |birth_country|residence_place|residence_country|nickname               |hobbies                                                     |occupation          |education                                                                                                                              |family                                                                                                                        |lang                  |coach                                                             |reason                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |hero                                                                                                                                                                                                |influence                                                                                                                     |philosophy                                                                                                                                                 |sporting_relatives                                                                                                                                                                                                                                                                                                 |ritual                                                                                                                                                                                                             |other_sports                                                                                                        |
# +----+-------+---------------------+--------------+---------------------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+---------------------------------+-------------------------------------------------------------+----------+--------------------+-------------+---------------+-----------------+-----------------------+------------------------------------------------------------+--------------------+---------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+----------------------+------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------+
# |NULL|NULL   |DELAERE Antonia      |DELAERE A     |Antonia DELAERE      |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Basketball']                   |['Women']                                                    |1994-08-01|ANTWERP             |Belgium      |ANTWERP        |Belgium          |                       |Loves to travel                                             |Athlete             |                                                                                                                                       |                                                                                                                              |                      |Club: Roberto Iniguez (ESP).<br>National: Rachid Meziane (FRA)    |Was advised by her doctor to take up a sport after being diagnosed with asthma                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                    |                                                                                                                              |“As an athlete, I think it’s super important to keep working hard because if you stop working hard, someone will pass you.” (womenshealth.com, 26 Aug 2022)|                                                                                                                                                                                                                                                                                                                   |Before a game she has a power nap and a good meal, usually pasta. Likes to wear a headband given to her by her boyfriend                                                                                           |                                                                                                                    |
# |NULL|NULL   |LINSKENS Kyara       |LINSKENS K    |Kyara LINSKENS       |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Basketball']                   |['Women']                                                    |1996-11-13|BRUGES              |Belgium      |BREDENE        |Belgium          |                       |                                                            |Athlete             |                                                                                                                                       |                                                                                                                              |Dutch                 |Club: Valery Demory (FRA).<br>National: Rachid Meziane (FRA)      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |                                                                                                                                                                                                                                                                                                                   |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |LISOWA MBAKA Maxuella|LISOWA MBAKA M|Maxuella LISOWA MBAKA|Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Basketball']                   |['Women']                                                    |2001-05-14|                    |             |FLERIUS        |Belgium          |                       |                                                            |Athlete             |                                                                                                                                       |                                                                                                                              |                      |National: Rachid Meziane (FRA).<br>Club: Rachid Meziane (FRA)     |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |                                                                                                                                                                                                                                                                                                                   |                                                                                                                                                                                                                   |3x3 basketball: Represented Belgium at the 2017 U18 Europe Cup                                                      |
# |NULL|NULL   |MASSEY Becky         |MASSEY B      |Becky MASSEY         |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Basketball']                   |['Women']                                                    |2000-03-21|OSTEND              |Belgium      |               |                 |                       |                                                            |Athlete             |                                                                                                                                       |Twin sister, Billie Massey                                                                                                    |                      |Club: Azu Muguruza (ESP).<br>National: Rachid Meziane (FRA)       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |Twin sister, Billie Massey (basketball), played at Olympic Games Tokyo 2020 and the 2022 World Cup                                                                                                                                                                                                                 |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |MASSEY Billie        |MASSEY B      |Billie MASSEY        |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Basketball']                   |['Women']                                                    |2000-03-21|OSTEND              |Belgium      |BREDENE        |Belgium          |                       |                                                            |Athlete             |                                                                                                                                       |Twin sister, Becky                                                                                                            |Dutch, English        |Club: David Gallego (ESP).<br>National: Rachid Meziane (FRA)      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |Twin sister, Becky Massey (basketball), member of 2023 EuroBasket-winning team                                                                                                                                                                                                                                     |                                                                                                                                                                                                                   |3x3 basketball: Played for Belgium, was part of the team that won the 2018 U18 Europe Cup event in Debrecen, Hungary|
# |NULL|NULL   |MEESSEMAN Emma       |MEESSEMAN E   |Emma MEESSEMAN       |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Basketball']                   |['Women']                                                    |1993-05-13|YPRES               |Belgium      |YPRES          |Belgium          |                       |                                                            |Athlete             |Studied Physical Education at the Free University of Brussels (BEL)                                                                    |Mother, Sonja Tankrey                                                                                                         |Dutch, English, French|National: Rachid Meziane (FRA).<br>Club: Valerie Garnier (FRA)    |Followed her mother's footsteps into basketball but was never forced into the sport. "It was not because my mom pushed me to play basketball - she always let me have a choice. And then, after a while, I just wanted to be better than my mom... The main thing for me and my brother was to play a sport. But as I grew up, I think my talent for basketball began to show more and more, so it was an easy choice for me to become a basketball player."  (olympics.com, 15 Jun 2021)|                                                                                                                                                                                                    |Her mother                                                                                                                    |                                                                                                                                                           |Mother, Sonja Tankrey (basketball), was named 1983 Belgian Women's Player of the Year                                                                                                                                                                                                                              |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |RAMETTE Elise        |RAMETTE E     |Elise RAMETTE        |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Basketball']                   |['Women']                                                    |1998-11-03|                    |             |YPRES          |Belgium          |                       |                                                            |Athlete             |Studied Physiotherapy at the University of Ghent (BEL)                                                                                 |                                                                                                                              |                      |National: Rachid Meziane (FRA).<br>Club: Fabian Tellez (ESP)      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |                                                                                                                                                                                                                                                                                                                   |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |RESIMONT Laure       |RESIMONT L    |Laure RESIMONT       |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Basketball']                   |['Women']                                                    |1998-01-29|                    |             |               |Belgium          |                       |                                                            |Athlete             |                                                                                                                                       |                                                                                                                              |                      |National: Rachid Meziane (FRA).<br>Club: Arvid Diels (BEL)        |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |                                                                                                                                                                                                                                                                                                                   |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |BROEKX Lize          |BROEKX L      |Lize BROEKX          |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Canoe Sprint']                 |["Women's Kayak Single 500m", "Women's Kayak Double 500m"]   |1992-04-05|NEERPELT            |Belgium      |NEERPELT       |Belgium          |                       |                                                            |Athlete, biochemist |Graduated with a Bachelor's degree (2013) and Master's (2017) in Biochemistry, Biotechnology at Catholic University of Leuven (Belgium)|Father, Erik                                                                                                                  |Dutch, English        |National: Carlos Prendes (BEL), Bob Maesen (BEL)                  |Her family loved the sport                                                                                                                                                                                                                                                                                                                                                                                                                                                               |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |Uncle, Paul (canoe sprint), represented Belgium at the 1976 Montreal Olympic Games. </p><p>Uncle, Jos (canoe sprint), represented Belgium at three Olympic Games - Munich 1972, Montreal 1976 and Moscow 1980                                                                                                      |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |PETERS Artuur        |PETERS A      |Artuur PETERS        |Male  |Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Canoe Sprint']                 |["Men's Kayak Single 1000m"]                                 |1996-10-26|HECHTEL-EKSEL       |Belgium      |HECHTEL-EKSEL  |Belgium          |                       |                                                            |Athlete             |                                                                                                                                       |Father, Walter. Mother, Leen. Older brother, William. Older sister, Hermien                                                   |Dutch, English        |National: Bob Maesen (BEL), Carlos Prendes (BEL)                  |First took up swimming but after some time decided he did not like it. He was looking for another sport so he and his siblings enrolled in a kayak introductory course. "We never stopped since then." (hechtel-eksel.be, 14 Jul 2021)                                                                                                                                                                                                                                                   |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |Brother, William (canoe sprint, quadrathlon), represented Belgium at the European Canoe Sprint Championships and is a world and European champion in quadrathlon (swimming, cycling, kayaking, running).</p><p>Sister, Hermien (canoe sprint), finished sixth in the K1 500m and ninth in the K2 500m at Tokyo 2020|                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |PETERS Hermien       |PETERS H      |Hermien PETERS       |Female|Athlete |BEL         |Belgium|Belgium     |Belgium    |Belgium         |BEL             |NULL  |NULL  |['Canoe Sprint']                 |["Women's Kayak Single 500m", "Women's Kayak Double 500m"]   |1994-11-19|HECHTEL-ESKEL       |Belgium      |HECHTEL-ESKEL  |Belgium          |                       |                                                            |Athlete, dietician  |                                                                                                                                       |Father, Walter. Mother, Leen. Brothers William and Artuur                                                                     |Dutch, English        |National: Carlos Prendes (BEL), Bob Maesen (BEL)                  |She became involved in the sport because her younger brother Artuur wanted to paddle                                                                                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |Brother, Artuur (canoe sprint), represented Belgium at the Tokyo 2020 Olympic Games.</p><p>Brother, William (canoe sprint, quadrathlon), represented Belgium at the European Canoe Sprint Championships and is a world and European champion in quadrathlon (swimming, cycling, kayaking, running)                 |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |ALAPHILIPPE Julian   |ALAPHILIPPE J |Julian ALAPHILIPPE   |Male  |Athlete |FRA         |France |France      |France     |France          |FRA             |NULL  |NULL  |['Cycling Road']                 |["Men's Road Race"]                                          |1992-06-11|SAINT-AMAND-MONTROND|France       |               |Andorra          |Loulou, Alafpolak, Juju|                                                            |Athlete             |                                                                                                                                       |Partner, Marion. Son, Nino (2021). Father, Jacques (deceased). Mother, Catherine. Younger brother, Bryan. Younger brother, Leo|English, French       |                                                                  |He was a drummer in his dad's dance band but liked the energy of cycling. “My father was an orchestra conductor for many years, so maybe that’s why I love music and rhythm. Like riding, music gives me an outlet for my energy”. (etixx-quickstep.com)                                                                                                                                                                                                                                 |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |Brother, Bryan (road cycling), rode in the French Continental ranks for the Equipe Cycliste Armée de Terre and St Michel - Auber93.</p><p>Partner, Marion Rousse (road cycling), won the French national road title in 2012 and was appointed race director of Tour de France Femmes in 2021                       |"Before the start of a race I close my eyes for a few seconds and think of my family and doing my best to help the team win or get the victory myself, if there's a race that suits me." (soudal-quickstepteam.com)|                                                                                                                    |
# |NULL|NULL   |ANDRE Sylvain        |ANDRE S       |Sylvain ANDRE        |Male  |Athlete |FRA         |France |France      |France     |France          |FRA             |NULL  |NULL  |['Cycling BMX Racing']           |['Men']                                                      |1992-10-14|CAVAILLON           |France       |CAVAILLON      |France           |The Big                |Cars, mountain biking, spending time with family and friends|Athlete             |                                                                                                                                       |Wife, Eva Ailloud. Daughter, LouLou. Son, Nino                                                                                |English, French       |National: Julien Sastre (FRA).<br>Personal: Nicolas Arschoot (FRA)|A friend of his father, who was riding, told him to try it out. "BMX is really the school of cycling, and as a kid you can only appreciate it - you make friends, you have fun and on weekends, you compete. That's everything I love." (myInfo)                                                                                                                                                                                                                                         |BMX cyclist Arthur Pilard (FRA), two-time 2021 European champion (BMX, team time trial)                                                                                                             |                                                                                                                              |                                                                                                                                                           |Wife, Eva Ailloud (BMX racing), 2012 European champion, 2009 world championship silver medallist, 2008 junior world championship bronze medallist                                                                                                                                                                  |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |BERTEAU Victoire     |BERTEAU V     |Victoire BERTEAU     |Female|Athlete |FRA         |France |France      |France     |France          |FRA             |NULL  |NULL  |['Cycling Road', 'Cycling Track']|["Women's Road Race", "Women's Team Pursuit"]                |2000-08-16|LAMBRES-LEZ-DOUAI   |France       |BOURGES        |France           |                       |                                                            |Armed forces athlete|                                                                                                                                       |Partner, Saartje Vandenbroucke                                                                                                |French                |National: Samuel Monnerais (FRA)                                  |First practised dance alongside her sister while their brother practised cycling. Eventually took up cycling and stayed in the sport despite her brother quitting. Coach Alain Midelet (FRA) encouraged her to try track cycling. “It was him who pushed me to the track. He told me, 'You'll ride on a track bike, you have no other option’. When you are in the minor ranks, the track is frightening. It's not like everybody wanted to practise it, like cyclo-cross.” (myInfo)     |Cyclist Laura Trott-Kenny (GBR), six-time Olympic medallist (five gold, one silver) over three Games (2012, 2016, 2020), 15-time world championship medallist (seven gold, seven silver, one bronze)|Coach Alain Midelet (FRA). Her mother                                                                                         |                                                                                                                                                           |Partner, Saartje Vandenbroucke (cycling road), represents Belgium                                                                                                                                                                                                                                                  |                                                                                                                                                                                                                   |                                                                                                                    |
# |NULL|NULL   |BORRAS Marion        |BORRAS M      |Marion BORRAS        |Female|Athlete |FRA         |France |France      |France     |France          |FRA             |NULL  |NULL  |['Cycling Track']                |["Women's Madison", "Women's Team Pursuit"]                  |1997-11-24|PONTCHARRA          |France       |GRENOBLE       |France           |                       |                                                            |Athlete, student    |Physiotherapy - University School of Physiotherapy Center Val de Loire, Orleans, FRA                                                   |                                                                                                                              |English, French       |National, endurance: Samuel Monnerais (FRA)                       |She wanted to try athletics and went to a forum in Isere, France, where the stands for the local athletics and cycling federations were side by side. There she was introduced to cycling. She tried mountain biking, cyclo-cross, and road cycling before taking up track                                                                                                                                                                                                               |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |                                                                                                                                                                                                                                                                                                                   |                                                                                                                                                                                                                   |Road cycling: Bronze medallist in time trial at the 2024 national championships                                     |
# |NULL|NULL   |BOUDAT Thomas        |BOUDAT T      |Thomas BOUDAT        |Male  |Athlete |FRA         |France |France      |France     |France          |FRA             |NULL  |NULL  |['Cycling Track']                |["Men's Madison", "Men's Omnium", "Men's Team Pursuit"]      |1994-02-24|LANGON              |France       |               |                 |                       |                                                            |Athlete             |                                                                                                                                       |                                                                                                                              |French                |National, endurance: Steven Henry (FRA)                           |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                    |                                                                                                                              |                                                                                                                                                           |                                                                                                                                                                                                                                                                                                                   |                                                                                                                                                                                                                   |                                                                                                                    |
# ...
# |NULL|NULL   |ABDALLA Yaseen            |ABDALLA Y     |Yaseen ABDALLA            |Male  |Athlete |SUD         |Sudan  |Sudan       |Sudan      |Sudan           |SUD             |NULL  |NULL  |['Athletics']        |["Men's Marathon"]                                                                                                                                                                             |2001-08-13|                 |             |                   |United States    |            |                                                                  |Athlete, student|Attended the University of Texas (Austin, USA) and the University of Tennessee (Knoxville, USA). He will transfer to the University of Arkansas (Fayetteville, USA) in autumn 2024                                                                                                                   |Father, Ahmed. Mother, Amira. Brothers, Yousuf, Yahya and Yazeed  |English                    |                                                   |“My parents thought I’d be good at [athletics] for some reason." (runnersworld.com, 25 Mar 2022)                                                                                                                                                                                                                                                                                    |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |“There have been so many people who are more talented than me, faster, with better endurance or better support systems. The only difference between me and them is at some point, they stopped coming to practice and I didn’t.” (runnersworld.com, 25 Mar 2022)|                                                                                                                                                            |                                                                                                          |                                                                                           |
# |NULL|NULL   |ELBAKH Faris Ibrahim E    |ELBAKH FIE    |Faris Ibrahim E ELBAKH    |Male  |Athlete |QAT         |Qatar  |Qatar       |Qatar      |Qatar           |QAT             |NULL  |NULL  |['Weightlifting']    |["Men's 102kg"]                                                                                                                                                                                |1998-06-04|                 |             |DOHA               |Qatar            |Meso Hassona|Travelling, camping, riding horses                                |Athlete         |                                                                                                                                                                                                                                                                                                     |Father, Ibrahim Elbakh                                            |Arabic, English            |Personal: Ibrahim Elbakh (EGY), his father         |“I was born into a family where my father and my brothers were all great lifters so weightlifting for me is not just a sport. It's really my family, my job, lifestyle, and passion.” (myInfo)</p><p>“What I love the most about weightlifting is that I get to challenge others without any fighting. I challenge others only through the bar to see who is stronger.” (olympic.qa)|                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |His father. “My dad has always encouraged me to give my very best, and has worked to build up my self-confidence, saying, ‘Fares, you can do anything you want as long as you have confidence in yourself and in your ability’. My dad understands me like no other - I don’t have to explain when I’m tired for example, as he knows what I need, and we understand each other... He can deal with me on a number of different levels: he is my coach in the gym, my father at home, and my friend outside the house.” (newarab.com, 3 Aug 2021)|“You have to think about beating the weights, you have to think that you're more powerful than what you are lifting.” (myInfo)                                                                                                                                  |Father, Ibrahim Elbakh (weightlifting), represented Egypt at two Olympic Games, placing fifth in 1984 (light-heavyweight) and DNFed in 1992 (heavyweight II)|                                                                                                          |                                                                                           |
# |NULL|NULL   |EISSA Seif                |EISSA S       |Seif EISSA                |Male  |Athlete |EGY         |Egypt  |Egypt       |Egypt      |Egypt           |EGY             |NULL  |NULL  |['Taekwondo']        |['Men -80kg']                                                                                                                                                                                  |1998-06-15|CAIRO            |Egypt        |CAIRO              |Egypt            |            |                                                                  |Athlete         |Arab Academy for Science, Technology and Maritime Transport (EGY)                                                                                                                                                                                                                                    |Wife, Habiba Essam (married 2022)                                 |Arabic, English            |National: Mohamed Magdy (EGY), Usama Sayed (EGY)   |                                                                                                                                                                                                                                                                                                                                                                                    |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |His father                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |"When it comes to training and competition, having the support of family plays a key role in an athlete's success." (gulftoday.ae, 10 Jun 2020)</p><p>"All Power Belongs To Allah." (Athlete Instagram, 11 Dec 2023)                                            |                                                                                                                                                            |                                                                                                          |                                                                                           |
# +----+-------+--------------------------+--------------+--------------------------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+---------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-----------------+-------------+-------------------+-----------------+------------+------------------------------------------------------------------+----------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------+---------------------------+---------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
#
# Batch: 2
# -------------------------------------------
# +----+-------+-----------------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+----------------+------+----------+-----------+-------------+---------------+-----------------+------------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
# |code|current|name                   |name_short|name_tv|gender|function|country_code|country|country_long|nationality|nationality_long|nationality_code|height|weight|disciplines     |events|birth_date|birth_place|birth_country|residence_place|residence_country|nickname          |hobbies|occupation|education|family|lang|coach|reason|hero|influence|philosophy|sporting_relatives|ritual|other_sports|
# +----+-------+-----------------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+----------------+------+----------+-----------+-------------+---------------+-----------------+------------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
# |NULL|NULL   |LUCAS FICTÍCIO DA SILVA|NULL      |NULL   |NULL  |NULL    |NULL        |NULL   |NULL        |BRAZIL     |NULL            |NULL            |1.75  |80.0  |DATA_ENGINEERING|NULL  |1995-10-20|SÃO PAULO  |BRAZIL       |NATAL          |BRAZIL           |O Mestre dos Dados|NULL   |NULL      |NULL     |NULL  |NULL|NULL |NULL  |NULL|NULL     |NULL      |NULL              |NULL  |NULL        |
# +----+-------+-----------------------+----------+-------+------+--------+------------+-------+------------+-----------+----------------+----------------+------+------+----------------+------+----------+-----------+-------------+---------------+-----------------+------------------+-------+----------+---------+------+----+-----+------+----+---------+----------+------------------+------+------------+
